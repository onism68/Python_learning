# %%
import json
import requests

url = "https://club.jd.com/comment/getProductPageFoldComments.action?productId=7631419&score=0&sortType=5&page=0&pageSize=10&_=1541765965829"
res = requests.get(url)
#text1 = res.text
#text2 = text1.lstrip('jQuery9944882(').rstrip(');')
js = json.loads(res.text)
js
# Out:
# {'productAttr': None,
#  'productCommentSummary': {'beginRowNumber': 0,
#   'endRowNumber': 0,
#   'skuId': 7631419,
#   'productId': 7631419,
#   'score1Count': 528,
#   'score2Count': 182,
#   'score3Count': 610,
#   'score4Count': 1829,
#   'score5Count': 142296,
#   'defaultGoodCount': 391103,
#   'showCount': 20612,
#   'commentCount': 536548,
#   'averageScore': 5,
#   'goodCount': 535228,
#   'goodRate': 0.99,
#   'goodRateShow': 99,
#   'goodRateStyle': 148,
#   'generalCount': 792,
#   'generalRate': 0.01,
#   'generalRateShow': 1,
#   'generalRateStyle': 2,
#   'poorCount': 528,
#   'poorRate': 0.0,
#   'poorRateShow': 0,
#   'poorRateStyle': 0,
#   'afterCount': 1222,
#   'plusCount': 0,
#   'videoCount': 619,
#   'oneYear': 0},
#  'maxPage': 100,
#  'score': 0,
#  'comments': [{'id': 12149610572,
#    'topped': -2,
#    'guid': '7fdc4b1f-f36a-438b-b837-96e776e2c528',
#    'content': '一直用这个牌子，可以',
#    'creationTime': '2018-11-17 16:06:06',
#    'isTop': False,
# ...
