# %%
import json
import requests

headers = {
    'Host': 'app.jike.ruguoapp.com',
    'Cookie': 'jike:config:searchPlaceholderLastInfo=1541860501572#0',
    'os-version': '26',
    'os': 'android',
    'app-buildno': '712',
    'manufacturer': 'Xiaomi',
    'model': 'MI 6',
    'app-version': '4.14.2',
    'x-jike-device-id':'b6dd5dce-29f3-4bcb-99e6-66148be19d1b',
    'applicationid': 'com.ruguoapp.jike',
    'market': 'xiaomi',
    'resolution': '1080x1920',
    'notificationenabled': 'true',
    'wificonnected': 'true',
    'x-jike-access-token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....TFm904_hi43ARGVnYLwfhRgYIkFUK8h-LOeLsLzfw40',
    'user-agent': 'okhttp/3.11.0',    
}
url = 'https://app.jike.ruguoapp.com/1.0/topics/getDetail?ref=HEADLINE_HOT&id=54eee25fe4b0b0057177fc59'
res = requests.get(url , headers=headers )
js = json.loads(res.text)
js
# Out:
# {'success': True,
#  'data': {'id': '54eee25fe4b0b0057177fc59',
#   'type': 'TOPIC',
#   'messagePrefix': '热门网络梗普及',
#   'content': '热门网络梗普及',
#   'topicId': 129,
#   'briefIntro': '无限大的网络无限多的梗，谁也不知道下一个火的是哪个，即刻为你普及网络热梗。',
#   'timeForRank': '2015-03-26T04:47:38.319Z',
#   'lastMessagePostTime': '2018-11-10T13:03:51.126Z',
#   'createdAt': '2015-02-26T09:07:43.179Z',
#   'updatedAt': '2018-11-10T15:00:16.844Z',
#   'subscribersCount': 1100000,
#   'subscribedStatusRawValue': 0,
#   'topicType': 'OFFICIAL',
#   'isAnonymous': False,
#   'isDreamTopic': False,
#   'isValid': True,
#   'operateStatus': 'ONLINE',
#   'rectanglePicture': {'thumbnailUrl': 'https://pic-txcdn.ruguoapp.com/o_1a927rbmm1l2mabv1i7s15h0u8a1k.png?imageView2/1/w/120/h/180/format/jpeg/q/80',
#    'middlePicUrl': 'https://pic-txcdn.ruguoapp.com/o_1a927rbmm1l2mabv1i7s15h0u8a1k.png?imageView2/1/w/200/h/300/format/jpeg/q/80',
# ...

# %%
header = {
    'Host': 'app.jike.ruguoapp.com',
    'Cookie': 'jike:config:searchPlaceholderLastInfo=1541860501572#0',
    'os-version': '26',
    'os': 'android',
    'app-buildno': '712',
    'manufacturer': 'Xiaomi',
    'model': 'MI 6' ,
    'app-version': '4.14.2',
    'x-jike-device-id': 'b6dd5dce-29f3-4bcb-99e6-66148be19d1b',
    'applicationid': 'com.ruguoapp.jike',
    'market': 'xiaomi',
    'resolution': '1080x1920',
    'notificationenabled':'true',
    'wificonnected': 'true',
    'x-jike-access-token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....TFm904_hi43ARGVnYLwfhRgYIkFUK8h-LOeLsLzfw40',
    'content-type': 'application/json; charset=utf-8',
    'user-agent': 'okhttp/3.11.0',
    
    
}

data = {
    "loadMoreKey":"5aa63bf60000000000000000",
    "topic":"54eee25fe4b0b0057177fc59",
}

url = 'https://app.jike.ruguoapp.com/1.0/messages/history'
res = requests.post(url,headers=header,data =data)
#js = json.loads(res.text)
#js
res.text
# Out:
# 'Bad Request'
