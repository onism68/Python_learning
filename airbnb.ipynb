# %%
import requests
import json

url = 'https://zh.airbnb.com/api/v2/explore_tabs?version=1.3.9&satori_version=1.0.12&_format=for_explore_search_web&experiences_per_grid=20&items_per_grid=30&guidebooks_per_grid=20&auto_ib=true&fetch_filters=true&has_zero_guest_treatment=true&is_guided_search=true&is_new_cards_experiment=true&luxury_pre_launch=true&query_understanding_enabled=false&show_groupings=true&supports_for_you_v3=true&timezone_offset=480&client_session_id=e536597c-8eee-4deb-8855-458bf94c3703&metadata_only=false&is_standard_search=true&refinement_paths%5B%5D=%2Fhomes&selected_tab_id=home_tab&click_referer=t%3ASEE_ALL%7Csid%3A5146e58f-edb6-41c1-a36f-7d370662fb65%7Cst%3AMAGAZINE_HOMES&title_type=MAGAZINE_HOMES&allow_override%5B%5D=&s_tag=2fOHfuMx&section_offset=0&items_offset=30&last_search_session_id=7dd71e9d-7c2a-458f-9ed9-6170d368b150&federated_search_session_id=c4d00c93-ddb6-4eb3-a5c5-e41cd326e3fe&screen_size=large&query=Shenzhen%2C%20China&_intents=p1&key=d306zoyjsyarp7ifhu67rjxn52tv0t20&currency=CNY&locale=zh'
res = requests.get(url)
js = json.loads(res.text)

# %%
list = js['explore_tabs'][0]['sections'][0]['listings']
list[0]
# Out:
# {'listing': {'badges': [],
#   'bathroom_label': '1间卫生间',
#   'bathrooms': 1.0,
#   'bed_label': '1张床',
#   'bedroom_label': '1间卧室',
#   'bedrooms': 1,
#   'beds': 1,
#   'city': '深圳',
#   'guest_label': '2位房客',
#   'host_languages': ['zh', 'en', 'ja', 'ko'],
#   'host_thumbnail_url_small': 'https://z1.muscache.cn/im/pictures/user/12af6de2-71a2-4d6e-b307-8fef7706ebda.jpg?aki_policy=profile_small',
#   'host_thumbnail_url': 'https://z1.muscache.cn/im/pictures/user/12af6de2-71a2-4d6e-b307-8fef7706ebda.jpg?aki_policy=profile_x_medium',
#   'id': 16784138,
#   'is_business_travel_ready': False,
#   'is_fully_refundable': True,
#   'is_host_highly_rated': True,
#   'is_new_listing': False,
#   'is_superhost': False,
#   'kicker_content': {'messages': ['整套公寓', '1室1卫1床'], 'text_color': '#03150D'},
#   'lat': 22.54557028238736,
#   'lng': 114.11369669478401,
#   'localized_city': '深圳',
#   'name': 'New【云邸】设计师风格现代高层公寓,靠近罗湖口岸万象城kkmall地王,去香港方便｡',
#   'person_capacity': 2,
# ...

# %%
len(list)
# Out:
# 30
