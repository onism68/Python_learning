# %%
import requests
import json

def appCate():
    urlCate = 'https://mobile.baidu.com/api/cate?f0=home_homeHeader%400'
    resCate = requests.get(urlCate)
    jsonResCate = json.loads(resCate.text)
    cateNames = jsonResCate['data']['soft']
    for i in range(len(cateName)):
        board_id = cateNames[i]['board_id']
        print(board_id)

# %%
#appCate()

urlCateDetail = 'https://mobile.baidu.com/api/board?boardid=board_101_0311&pn=1'
resCateDetail = requests.get(urlCateDetail)
jsonCateDetail = json.loads(resCateDetail.text)
dataCateDetail = jsonCateDetail['data']['data']
dataCateDetailtotal = jsonCateDetail['data']['total']


dataCateDetail
# Out:
# [{'docid': '25301072',
#   'packageid': '858468',
#   'package': 'com.duowan.kiwi',
#   'sname': '虎牙直播',
#   'icon': '//timg01.bdimg.com/timg?appsite&quality=100&size=b219_219&sec=1546785547&nocache&di=101324fd690e0ca2b49b7b2e38422080&src=http%3A%2F%2Fgdown.baidu.com%2Fimg%2F0%2F512_512%2Fc084baf92abcf928f6ff423f6a6bd8dc.png',
#   'type': 'soft',
#   'showSize': '47.14MB',
#   'manual_brief': '看王者直播，全英雄皮肤随机送',
#   'strDownload': '3695万',
#   'downloadUrl': 'http://m.gdown.baidu.',
# ...
